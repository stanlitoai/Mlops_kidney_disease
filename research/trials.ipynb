# %%
# !pip list
# Out:
# Package                      Version      Editable project location
# ---------------------------- ------------ -----------------------------------------------------------
# absl-py                      2.0.0
# aiofiles                     23.2.1
# aiohttp                      3.8.6
# aiohttp-retry                2.8.3
# aiosignal                    1.3.1
# alembic                      1.12.1
# altair                       5.1.2
# amqp                         5.1.1
# annotated-types              0.6.0
# antlr4-python3-runtime       4.9.3
# anyio                        3.7.1
# appdirs                      1.4.4
# argon2-cffi                  23.1.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.3.0
# asttokens                    2.4.1
# astunparse                   1.6.3
# async-lru                    2.0.4
# async-timeout                4.0.3
# asyncssh                     2.14.0
# atpublic                     4.0
# attrs                        23.1.0
# ...

# %%
from Mlops.components.
