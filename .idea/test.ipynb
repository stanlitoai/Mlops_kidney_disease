# %%
print("Hello world")
# Out:
# Hello world

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# absl-py                       2.0.0
# ai-tools                      0.3.9
# aiohttp                       3.8.5
# aiohttp-retry                 2.8.3
# aiosignal                     1.3.1
# alabaster                     0.7.13
# alembic                       1.12.0
# altair                        5.1.2
# amqp                          5.1.1
# annotated-types               0.6.0
# antlr4-python3-runtime        4.9.3
# appdirs                       1.4.4
# arabic-reshaper               3.0.0
# asn1crypto                    1.5.1
# asttokens                     2.4.0
# async-timeout                 4.0.3
# asyncssh                      2.14.0
# atpublic                      4.0
# attrs                         23.1.0
# Babel                         2.13.0
# backcall                      0.2.0
# beautifulsoup4                4.12.2
# billiard                      4.1.0
# ...

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# absl-py                       2.0.0
# ai-tools                      0.3.9
# aiohttp                       3.8.5
# aiohttp-retry                 2.8.3
# aiosignal                     1.3.1
# alabaster                     0.7.13
# alembic                       1.12.0
# altair                        5.1.2
# amqp                          5.1.1
# annotated-types               0.6.0
# antlr4-python3-runtime        4.9.3
# appdirs                       1.4.4
# arabic-reshaper               3.0.0
# asn1crypto                    1.5.1
# asttokens                     2.4.0
# async-timeout                 4.0.3
# asyncssh                      2.14.0
# atpublic                      4.0
# attrs                         23.1.0
# Babel                         2.13.0
# backcall                      0.2.0
# beautifulsoup4                4.12.2
# billiard                      4.1.0
# ...
